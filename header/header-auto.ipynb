# %% [markdown]
# # Notebook pour l'écriture du TEIheader

# %% [markdown]
# Les `teiHeader` seront généré à partir des réponses du [form](https://docs.google.com/forms/d/e/1FAIpQLSczVG3VSlDDcI403e02jDjFJyUmcxvRhKmNePzl_TwLIC-9xQ/viewform?usp=**sharing**) mais certaines informations sont nécessaires pour que le lien soit fait avec les index qui sont nécessaire pour la partie indexation et que le document xml soit validé par Oxygen.
# On copie les informations du tableau dans le fichier .csv sans modifier l'ordre des colonnes et sans prendre en compte la première colonne "horodateur".
# Le résultat du header au plus complet est indiqué à titre d'exemple dans le document [header-front.xml] sur le dépôt Git.

# %% [markdown]
# ## Chargement des bibliothèques

# %%
import csv
import xml.etree.ElementTree as ET

# %% [markdown]
# ## Lecture du CSV
#
# Le fichier CSV associé est `header.csv` qui est dans le même dossier.
#
# La première colonne doit être :
# ``` cvs
#
# NomAuteur,PrenomAuteur,FicheISNI,DBI/ARK,TitreOuvrage,LieuEdition,Editeur,Date,USTC,BiblioConservation,PaysConservation,VilleConservation,LienReproduction,Droits,EditionsModernes,Traductions,BibliographieSelective,Licence,ContributeursEmmaBondoerffer,ContributeursAnaïsMazoué,ContributeursTeklia,ContributeursHippolyteFaré,ContributeursCortoRolaz,ContributeursOctavePhilibert,ContributeursAlessiaAvena,ContributeursYoussoufDiawara,ContributeursJuliaCastiglione,ContributeursAnnaSconza,NiveauTranscription,SpecificitesDuXML,StructureFichierXML
#
# ```
#
# Si jamais elle est supprimée dans le fichier header, il faut la recopier comme ci-dessus pour que la fonction de lecture du CSV reconnaisse les colonnes.

# %%
def lire_csv_header(fichier_header): #création d'une fonction pour lire les csv
    infos_header = [] #création d'une liste vide pour charger les données du csv
    try:
        with open(fichier_header, 'r', encoding='utf-8') as f:
            reader = csv.DictReader(f)
            for row in reader:
                # Vérification des colonnes nécessaires
                if row.get('TitreOuvrage') and row.get('NomAuteur'): 
                    infos_header.append({
                        'Nom': row['NomAuteur'].strip(),
                        'Prenom': row['PrenomAuteur'].strip(),
                        'ISNI': row['FicheISNI'].strip(),
                        'DBI/ARK': row['DBI/ARK'].strip(),
                        'Titre': row['TitreOuvrage'].strip(),
                        'pubPlace': row['LieuEdition'].strip(),
                        'Editeur': row['Editeur'].strip(),
                        'Date': row['Date'].strip(),
                        'USTC': row['USTC'].strip(),
                        'Bibliotheque': row['BiblioConservation'].strip(),
                        'PaysCons': row['PaysConservation'].strip(),
                        'VilleCons': row['VilleConservation'].strip(),
                        'LienReproduction': row['LienReproduction'].strip(),
                        'Droits': row.get('Droits', '').strip(),
                        'Emma Bondoerffer': row.get('ContributeursEmmaBondoerffer', '').strip(),
                        'Anaïs Mazoué': row.get('ContributeursAnaïsMazoué', '').strip(),
                        'Teklia': row.get('ContributeursTeklia', '').strip(),
                        'Hippolyte Faré': row.get('ContributeursHippolyteFaré', '').strip(),
                        'Corto Rolaz': row.get('ContributeursCortoRolaz', '').strip(),
                        'Octave Philibert': row.get('ContributeursOctavePhilibert', '').strip(),
                        'Alessia Avena': row.get('ContributeursAlessiaAvena', '').strip(),
                        'Youssouf Diawara': row.get('ContributeursYoussoufDiawara', '').strip(),
                        'Julia Castiglione': row.get('ContributeursJuliaCastiglione', '').strip(),
                        'Anna Sconza': row.get('ContributeursAnnaSconza', '').strip(),
                        'Irene Calcagno': row.get('ContributeursIreneCalcagno', '').strip(),
                        'Memofonte': row.get('ContributeursMemofonte', '').strip(),
                        'ATIR': row.get('ContributeursATIR', '').strip(), 
                        'Pierre Husson': row.get('ContributeursPierreHusson', '').strip(),
                        'Carla Tricon': row.get('ContributeursCarlaTricon', '').strip(),
                        'Nicolò Zanolli': row.get('ContributeursNicolòZanolli', '').strip(),
                        'Elisa Bonaiuti': row.get('ContributeursElisaBonaiuti', '').strip(),
                        'NiveauTranscription': "édition complète", # remplacer par édition synthétique ou complete
                        'SpecificitesXML': row.get('SpecificiteDuXML', '').strip(),
                        'StructureXML': row.get('StructureFichierXML', '').strip()
                    })
                else:
                    print(f"Ligne ignorée (champs manquants) : {row}") 
    except Exception as e: # il faut mettre un except quand on met try, permet de signaler les erreurs
        print(f"Erreur lors de la lecture du fichier CSV : {e}")
    print(infos_header)
    return infos_header

# %% [markdown]
# Cette cellule n'est pas nécessaire mais elle permet de vérifier le résultat de la fonction lire_csv_header

# %%
# Vérification de la liste crée avec les infos du csv.
fichier_header = 'header.csv'
lire_csv_header(fichier_header)
# Out:
# Ligne ignorée (champs manquants) : {'NomAuteur': 'Borghini', 'PrenomAuteur': 'Raffaele', 'FicheISNI': '', 'DBI/ARK': '', 'TitreOuvrage': '', 'LieuEdition': '', 'Editeur': '', 'Date': '', 'USTC': '', 'BiblioConservation': '', 'PaysConservation': '', 'VilleConservation': '', 'LienReproduction': '', 'Droits': '', 'EditionsModernes': '', 'Traductions': '', 'BibliographieSelective': 'Pascal Dubourg-Glatigny, "La question de la perspective matérielle dans les traités du Cinquecento", dans L\'artiste et l\'oeuvre à l\'épreuve de la perspective, dir. Marianne Cojannot-Le Blanc, Marisa Dalai Emiliani et Pascal Dubourg Glatigny, Rome, EFR, 2006, p. 365-384', 'Licence': '', 'ContributeursEmmaBondoerffer': '', 'ContributeursAnaïsMazoué': '', 'ContributeursTeklia': '', 'ContributeursHippolyteFaré': '', 'ContributeursCortoRolaz': '', 'ContributeursOctavePhilibert': '', 'ContributeursAlessiaAvena': '', 'ContributeursYoussoufDiawara': '', 'ContributeursJuliaCastiglione': '', 'ContributeursAnnaSconza': '', 'ContributeursIreneCalcagno': '', 'ContributeursMemofonte': '', 'ContributeursATIR': '', 'ContributeursPierreHusson': '', 'ContributeursCarlaTricon': '', 'ContributeursNicolòZanolli': '', 'ContributeursElisaBonaiuti': '', 'NiveauTranscription': '', 'SpecificitesDuXML': '', 'StructureFichierXML': '', None: ['', '', '', '', '']}
# [{'Nom': 'Bosse', 'Prenom': 'Abraham', 'ISNI': 'http://isni.org/isni/0000000121355423', 'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb118930604', 'Titre': "Sentimens sur la distinction des diverses manieres de peinture, dessein & graveure, & des originaux d'avec leurs copies. Ensemble du choix des sujets, & des chemins pour arriver facilement & promptement à bien pourtraire.", 'pubPlace': 'Paris', 'Editeur': 'Pierre Des Hayes', 'Date': '1649', 'USTC': 'http://catalogue.bnf.fr/ark:/12148/cb30134732p', 'Bibliotheque': 'Bibliothèque nationale de France', 'PaysCons': 'France', 'VilleCons': 'Paris', 'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/btv1b8612040z', 'Droits': 'Gallica, Bibliothèque nationale de France', 'Emma Bondoerffer': 'Transcription, Balisage, Indexation', 'Anaïs Mazoué': '', 'Teklia': '', 'Hippolyte Faré': '', 'Corto Rolaz': '', 'Octave Philibert': '', 'Alessia Avena': '', 'Youssouf Diawara': '', 'Julia Castiglione': '', 'Anna Sconza': '', 'Irene Calcagno': '', 'Memofonte': '', 'ATIR': '', 'Pierre Husson': '', 'Carla Tricon': 'Identification des œuvres', 'Nicolò Zanolli': '', 'Elisa Bonaiuti': '', 'NiveauTranscription': 'édition complète', 'SpecificitesXML': '', 'StructureXML': 'body avec div des heading Transkribus'}, {'Nom': 'Bosse', 'Prenom': 'Abraham', 'ISNI': 'http://isni.org/isni/0000000121355424', 'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb118930604', 'Titre': "Traité des pratiques géométrales et perspective enseignée dans l'Académie royale de peinture et scupture", 'pubPlace': 'Paris', 'Editeur': 'Antoine Cellier', 'Date': '1665', 'USTC': 'http://catalogue.bnf.fr/ark:/12148/cb30134737d', 'Bibliotheque': 'Bibliothèque nationale de France', 'PaysCons': 'France', 'VilleCons': 'Paris', 'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k1083747', 'Droits': 'Gallica, Bibliothèque nationale de France', 'Emma Bondoerffer': 'Transcription, Balisage, Indexation', 'Anaïs Mazoué': '', 'Teklia': '', 'Hippolyte Faré': '', 'Corto Rolaz': '', 'Octave Philibert': '', 'Alessia Avena': '', 'Youssouf Diawara': '', 'Julia Castiglione': '', 'Anna Sconza': '', 'Irene Calcagno': '', 'Memofonte': '', 'ATIR': '', 'Pierre Husson': '', 'Carla Tricon': 'Identification des œuvres', 'Nicolò Zanolli': '', 'Elisa Bonaiuti': '', 'NiveauTranscription': 'édition complète', 'SpecificitesXML': '', 'StructureXML': 'body avec div des heading Transkribus'}, {'Nom': 'Bosse', 'Prenom': 'Abraham', 'ISNI': 'http://isni.org/isni/0000000121355425', 'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb118930604', 'Titre': "Traicté des manieres de graver en taille douce sur l'airin . Par le Moyen des Eauxs Fortes, & des Vernix Durs & Mols. Ensemble de la façon d'en Imprimer les Planches, & d'en Construire la Presse, & autres choses concernans lesdits Arts.", 'pubPlace': 'Paris', 'Editeur': "chez ledit Bosse, en l'Isle du Palais, à la Rozerouge, devant la Megisserie", 'Date': '1645', 'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb40021779b', 'Bibliotheque': 'Bibliothèque nationale de France', 'PaysCons': 'France', 'VilleCons': 'Paris', 'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/btv1b8626172s', 'Droits': 'Gallica, Bibliothèque nationale de France', 'Emma Bondoerffer': 'Transcription, Balisage, Indexation', 'Anaïs Mazoué': '', 'Teklia': '', 'Hippolyte Faré': '', 'Corto Rolaz': '', 'Octave Philibert': '', 'Alessia Avena': '', 'Youssouf Diawara': '', 'Julia Castiglione': '', 'Anna Sconza': '', 'Irene Calcagno': '', 'Memofonte': '', 'ATIR': '', 'Pierre Husson': '', 'Carla Tricon': '', 'Nicolò Zanolli': '', 'Elisa Bonaiuti': '', 'NiveauTranscription': 'édition complète', 'SpecificitesXML': '', 'StructureXML': 'body avec div des heading Transkribus'}, {'Nom': 'Sanzio, Castiglione', 'Prenom': 'Raphaël, Baldassarre', 'ISNI': 'https://isni.org/isni/000000012136483X;  https://isni.org/isni/0000000121007795', 'DBI/ARK': 'https://data.bnf.fr/ark:/12148/cb12215591q ; https://data.bnf.fr/ark:/12148/cb123195492', 'Titre': 'Lettera a Leone X ...
# [{'Nom': 'Bosse',
#   'Prenom': 'Abraham',
#   'ISNI': 'http://isni.org/isni/0000000121355423',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb118930604',
#   'Titre': "Sentimens sur la distinction des diverses manieres de peinture, dessein & graveure, & des originaux d'avec leurs copies. Ensemble du choix des sujets, & des chemins pour arriver facilement & promptement à bien pourtraire.",
#   'pubPlace': 'Paris',
#   'Editeur': 'Pierre Des Hayes',
#   'Date': '1649',
#   'USTC': 'http://catalogue.bnf.fr/ark:/12148/cb30134732p',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/btv1b8612040z',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Transcription, Balisage, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Identification des œuvres',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'body avec div des heading Transkribus'},
#  {'Nom': 'Bosse',
#   'Prenom': 'Abraham',
#   'ISNI': 'http://isni.org/isni/0000000121355424',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb118930604',
#   'Titre': "Traité des pratiques géométrales et perspective enseignée dans l'Académie royale de peinture et scupture",
#   'pubPlace': 'Paris',
#   'Editeur': 'Antoine Cellier',
#   'Date': '1665',
#   'USTC': 'http://catalogue.bnf.fr/ark:/12148/cb30134737d',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k1083747',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Transcription, Balisage, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Identification des œuvres',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'body avec div des heading Transkribus'},
#  {'Nom': 'Bosse',
#   'Prenom': 'Abraham',
#   'ISNI': 'http://isni.org/isni/0000000121355425',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb118930604',
#   'Titre': "Traicté des manieres de graver en taille douce sur l'airin . Par le Moyen des Eauxs Fortes, & des Vernix Durs & Mols. Ensemble de la façon d'en Imprimer les Planches, & d'en Construire la Presse, & autres choses concernans lesdits Arts.",
#   'pubPlace': 'Paris',
#   'Editeur': "chez ledit Bosse, en l'Isle du Palais, à la Rozerouge, devant la Megisserie",
#   'Date': '1645',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb40021779b',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/btv1b8626172s',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Transcription, Balisage, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'body avec div des heading Transkribus'},
#  {'Nom': 'Sanzio, Castiglione',
#   'Prenom': 'Raphaël, Baldassarre',
#   'ISNI': 'https://isni.org/isni/000000012136483X;  https://isni.org/isni/0000000121007795',
#   'DBI/ARK': 'https://data.bnf.fr/ark:/12148/cb12215591q ; https://data.bnf.fr/ark:/12148/cb123195492',
#   'Titre': 'Lettera a Leone X, Mantova, Archivio Privato Castiglioni, documenti Sciolti, a), n. 12, [1519], dans Opere volgari, e latine del conte Baldessar Castiglione. Novellamente raccolte, ordinate, ricorrette, ed illustrate, come nella seguente lettera può vedersi, da Gio. Antonio, e Gaetano Volpi, p. 429-436',
#   'pubPlace': 'Padova',
#   'Editeur': 'Comino',
#   'Date': '1733',
#   'USTC': 'https://opac.sbn.it/risultati-ricerca-avanzata/-/opac-adv/index/1/ITICCULO1E003806?fieldvalue%5B1%5D=opere+volgari%2C+e+latine+del+conte+baldessar+castiglione.+novellamente+raccolte%2C+ordinate%2C+ricorrette%2C+ed+illustrate%2C+come+nella+seguente+lettera+puo+vedersi%2C+da+gio.+antonio%2C+e+gaetano+volpi+...&fieldaccess%5B1%5D=Titolo%3A4%3Anocheck&fieldstruct%5B1%5D=ricerca.frase_esatta%3A4%3D7&fieldop%5B1%5D=AND%3A%40and%40&struct%3A3008=ricerca.frase%3A4%3D1&item_nocheck%3A7017%3ATipo_spec_mat=&long_emisfero_a=&struct%3A8019=ricerca.parole_almeno_una%3A%40or%40&struct%3A3087=ricerca.parole_tutte%3A4%3D6&struct%3A3091=ricerca.parole_tutte%3A4%3D6&item_nocheck%3A1012%3AData_aggiornamento%3A4%3A4=&item_nocheck%3A3020%3AOrganico_analitico_composizione=&item_nocheck%3A1025%3ATonalita=&lat_primi_a=&_cacheid=1739899146086&long_primi_a=&long_gradi_da=&item_nocheck%3A7018%3ASupporto_prim=&long_secondi_a=&struct%3A5533=ricerca.parole_almeno_una%3A%40or%40&item_nocheck%3A7023%3ATipo=&item%3A3087%3AMarca=&item_nocheck%3A5515%3ATipo_materiale_video=&item_nocheck%3A7022%3ADes_fun=&struct%3A3022=ricerca.parole_tutte%3A4%3D6&long_gradi_a=&struct%3A3020=ricerca.parole_tutte%3A4%3D6&item%3A7002%3ARapporto_scala_or%3A4%3A4=&struct%3A1001=ricerca.parole_almeno_una%3A%40or%40&item_nocheck%3A3091%3ASegnatura=&struct%3A3024=ricerca.parole_tutte%3A4%3D6&filter%3A3088%3ABiblioteca=&item_nocheck%3A5521%3AMateriale_accompagnamento=&item_nocheck%3A7020%3ATec_dis=&lat_emisfero_a=&struct%3A3018=ricerca.parole_tutte%3A4%3D6&item%3A7003%3ARapporto_scala_ver%3A4%3A4=&item_nocheck%3A5011%3ATipo_elaborazione=&filter%3A31%3AAnno_pubblicazione%3A4%3A4=&item_nocheck%3A3041%3AIncipit=&item_nocheck%3A5528%3ATipo_suono=&item_nocheck%3A7004%3AMeridiano=&item_nocheck%3A5120%3AProiezione=&lat_emisfero_da=&long_secondi_da=&item_nocheck%3A5520%3ATecnica_registrazione=&item_nocheck%3A3008%3AImpronta=&item_nocheck%3A1001%3ATipo_documento_sonoro=&item_nocheck%3A1012%3AData_aggiornamento%3A2%3A4=&item_nocheck%3A3018%3AOrganico_sintetico_composizione=&item_nocheck%3A7019%3AColore_graf=&filter_nocheck%3A55%3APaese=&struct%3A3050=ricerca.parole_tutte%3A4%3D6&filter_nocheck%3A54%3ALingua=&item_nocheck%3A7000%3ATipo_scala=&lat_gradi_da=&item%3A7016%3ANote_contenuto_abstract=&item%3A3050%3APersonaggio=&item_nocheck%3A3022%3AOrganico_sintetico_elaborazione=&item%3A3058%3ALuogo=&item_nocheck%3A5530%3ATecnica_registrazione=&filter_nocheck%3A1021%3ALivello_bibliografico=&item_nocheck%3A5533%3AFormato=&item_nocheck%3A3024%3AOrganico_analitico_elaborazione=&item_nocheck%3A5516%3AColore_video=&item_nocheck%3A7001%3ATipo_scala=&lat_secondi_da=&item%3A7002%3ARapporto_scala_or%3A2%3A4=&lat_secondi_a=&lat_gradi_a=&struct%3A5522=ricerca.parole_almeno_una%3A%40or%40&item_nocheck%3A3090%3APresentazione=&item_nocheck%3A7021%3ATec_stampe=&item_nocheck%3A5529%3AMateriale_accompagnamento_sn=&item_nocheck%3A5522%3AFormato=&item%3A7003%3ARapporto_scala_ver%3A2%3A4=&long_emisfero_da=&struct%3A3058=ricerca.parole_tutte%3A4%3D6&struct%3A7016=ricerca.parole_tutte%3A4%3D6&long_primi_da=&filter%3A31%3AAnno_pubblicazione%3A2%3A4=&lat_primi_da=&item%3A3014%3AForma=',
#   'Bibliotheque': 'Bibliothèque nationale centrale de Florence',
#   'PaysCons': 'Italie',
#   'VilleCons': 'Florence',
#   'LienReproduction': 'https://books.google.fr/books?id=bAad_6Ro5AwC&printsec=frontcover&hl=fr&source=gbs_ge_summary_r&cad=0#v=onepage&q&f=false',
#   'Droits': 'Google books',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': 'Identification des œuvres',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Félibien',
#   'Prenom': 'Raphaël, Baldassarre',
#   'ISNI': 'http://isni.org/isni/0000000121355570',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb11902499b',
#   'Titre': 'Entretiens sur les vies et sur les ouvrages des plus excellens peintres anciens et modernes',
#   'pubPlace': 'Paris',
#   'Editeur': 'Pierre le Petit',
#   'Date': '1666-1688',
#   'USTC': 'http://catalogue.bnf.fr/ark:/12148/cb304252874',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k10402281',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Transcription, Balisage, Indexation',
#   'Anaïs Mazoué': 'Transcription, Balisage, Indexation',
#   'Teklia': 'Transcription',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': 'Transcription',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Indexation',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Fréart/Salvini',
#   'Prenom': 'Anton Maria',
#   'ISNI': 'https://isni.org/isni/0000000121260854; https://isni.org/isni/0000000121394238',
#   'DBI/ARK': 'https://data.bnf.fr/ark:/12148/cb11903494v; https://data.bnf.fr/fr/ark:/12148/cb12103637b',
#   'Titre': 'Idea della perfezione della pittura di m.r Rolando Freart tradotta dal francese da Anton Maria Salvini e pubblicata per la prima volta dal canonico Domenico Moreni con una dissertazione apologetica in fine di Michelangelo Buonarroti scritta dal sig. Onofrio Boni',
#   'pubPlace': 'Florence',
#   'Editeur': 'Appresso Carli e compo. in Borgo SS. Apostoli',
#   'Date': '1809',
#   'USTC': 'https://opac.sbn.it/risultati-ricerca-avanzata/-/opac-adv/index/1/ITICCURMRE002018?fieldvalue%5B1%5D=salvini%2C+idea+della+perfezione+della+pittura&fieldaccess%5B1%5D=Keywords%3A1016&fieldstruct%5B1%5D=ricerca.parole_tutte%3A4%3D6&struct%3A1001=ricerca.parole_almeno_una%3A%40or%40',
#   'Bibliotheque': 'Rome, Bibliotheca Hertziana, Max Planck Institut',
#   'PaysCons': 'Italie',
#   'VilleCons': 'Rome',
#   'LienReproduction': 'dlib.biblhertz.it/ghcha44514090',
#   'Droits': 'Rome, Bibliotheca Hertziana, Max Planck Institut',
#   'Emma Bondoerffer': 'Transcription, Structuration',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': 'Correction, Balisage, Indexation',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Identification des œuvres, Indexation',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + gap + dedicace + preface + avertissement) + body (2 chap : C1 = 5SC + C2 = 5SC [Stampa 4 pas identifiée])'},
#  {'Nom': 'Zuccari',
#   'Prenom': 'Federico',
#   'ISNI': 'https://isni.org/isni/0000000453031871',
#   'DBI/ARK': 'https://data.bnf.fr/ark:/12148/cb12412468j',
#   'Titre': "L’idea de'pittori, scultori, et architetti",
#   'pubPlace': 'Turin',
#   'Editeur': 'Agostino Disserolio',
#   'Date': '1607',
#   'USTC': 'https://www.ustc.ac.uk/editions/4033938',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k1912377t/f141.vertical',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': '',
#   'Teklia': 'Transcription',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': 'Correction, Structuration, Balisage, Indexation',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': 'Correction',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage) + body (17 chapitres)'},
#  {'Nom': 'Zuccari',
#   'Prenom': 'Federico',
#   'ISNI': 'https://isni.org/isni/0000000453031871',
#   'DBI/ARK': 'http://ark.bnf.fr/ark:/12148/cb12412468j',
#   'Titre': 'Lettera a prencipi, et signori amatori del dissegno, pittura, scultura, et architettura',
#   'pubPlace': 'Mantova',
#   'Editeur': 'Francesco Osanna',
#   'Date': '1605',
#   'USTC': 'à compléter',
#   'Bibliotheque': 'Google (à changer)',
#   'PaysCons': '',
#   'VilleCons': '',
#   'LienReproduction': '',
#   'Droits': '',
#   'Emma Bondoerffer': 'Balisage',
#   'Anaïs Mazoué': '',
#   'Teklia': 'Transcription',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': 'Correction, Structuration, Balisage, Indexation',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': 'Correction',
#   'Anna Sconza': 'Correction',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Identification des œuvres',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + eloges) + body (Lettre) + back (dedicace + postface)'},
#  {'Nom': 'Lomazzo',
#   'Prenom': 'Giovanni Paolo',
#   'ISNI': 'https://isni.oclc.org/cbs/DB=1.2/SET=1/TTL=1/CMD?ACT=SRCH&IKT=8006&SRT=LST_nd&TRM=Lomazzo',
#   'DBI/ARK': 'https://data.bnf.fr/ark:/12148/cb12358011k',
#   'Titre': 'Idea del tempio della pittura',
#   'pubPlace': 'Milano',
#   'Editeur': 'Paolo Gottardo Ponto',
#   'Date': '1590',
#   'USTC': 'https://www.ustc.ac.uk/editions/838469',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k111876v',
#   'Droits': 'Biblioteca nazionale centrale di Roma',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': 'Correction, Structuration, Balisage, Indexation',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': 'Transcription',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Indexation',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + dedicace + poemes) + body (L1 [38 chapitres])'},
#  {'Nom': 'Huret',
#   'Prenom': 'Grégoire',
#   'ISNI': 'http://isni.org/isni/0000000109120963',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb12191860s',
#   'Titre': 'La regle precise, pour descrire le profil eslevé du fust des colomnes, suivant une hauteur, grosseur, et retrécissement donné à discretion, demonstrée geometriquement. [...]',
#   'pubPlace': 'Paris',
#   'Editeur': 'Edme Martin',
#   'Date': '1665',
#   'USTC': 'http://catalogue.bnf.fr/ark:/12148/cb39316816c',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k1509638p.r=La%20regle%20precise%2C%20pour%20descrire%20le%20profil%20eslev%C3%A9%20du%20fust%20des%20colomnes?rk=21459;2',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Transcription, Correction, Structuration, Balisage, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + preface) + body (2 chapitres [43 et 10 section] + 1 conclusion)'},
#  {'Nom': 'Martin',
#   'Prenom': 'Jean',
#   'ISNI': 'https://isni.org/page/search-database/',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb12462195n',
#   'Titre': 'Le premier livre d’architecture de Sebastiano Serlio; Le second livre de perspective (1537- 1540 Antichità)',
#   'pubPlace': 'Paris',
#   'Editeur': 'Jean Barbé',
#   'Date': '1545',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb313544573',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://architectura.cesr.univ-tours.fr/Traite/Notice/ENSBA_LES1736.asp?param=',
#   'Droits': 'École nationale supérieure des beaux-arts de Paris',
#   'Emma Bondoerffer': 'Transcription, Correction, Structuration, Balisage, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': 'Correction, Structuration, Balisage, Indexation',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + eloge + errata) + body (2 livres) + back (avis)'},
#  {'Nom': 'Zuccari - Alberti',
#   'Prenom': 'Federico - Romano',
#   'ISNI': 'https://isni.org/isni/0000000453031871  - https://isni.org/isni/0000000398185535',
#   'DBI/ARK': 'https://data.bnf.fr/ark:/12148/cb12412468j - https://data.bnf.fr/en/ark:/12148/cb166044630',
#   'Titre': "Origine, et progresso dell'Academia del disegno, de pittori, scultori, &*.",
#   'pubPlace': 'Pavia',
#   'Editeur': 'Pietro Bartoli',
#   'Date': '1604',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb31692442x',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k111903m.image',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': 'Transcription, Correction, Structuration, Balisage, Indexation',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': 'Transcription, Correction, Structuration, Balisage, Indexation',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + poemes + avis) + body ('},
#  {'Nom': 'Marino',
#   'Prenom': 'Giovan Battista',
#   'ISNI': 'https://isni.org/isni/0000000121297454',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb12158025x',
#   'Titre': 'Dicerie sacre Diceria 1',
#   'pubPlace': 'Torino',
#   'Editeur': 'Luigi Pizzamiglio',
#   'Date': '1614',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb30885628n',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'à compléter',
#   'Droits': 'Bibliothèque nationale de France',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': 'Transcription, Structuration, Balisage, Indexation',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': 'Correction, Balisage, Indexation',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + lettres + dedicaces + poeme) + body (3 livres)'},
#  {'Nom': 'Martin',
#   'Prenom': 'Jean',
#   'ISNI': 'https://isni.org/isni/0000000076903637',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb12462195n',
#   'Titre': 'L’architecture et art de bien bastir du Seigneur Leon Baptiste Alberti',
#   'pubPlace': 'Paris',
#   'Editeur': 'Jacques Kerver',
#   'Date': '1553',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb30007826z',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k85631r',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Transcription, Correction, Structuration, Balisage, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + lettres + privilege + gap + avis + preface) + body (10 livres L avec des chapitres C)'},
#  {'Nom': 'Pader',
#   'Prenom': 'Hilaire',
#   'ISNI': 'https://isni.oclc.org/cbs/DB=1.2/CMD?ACT=SRCH&IKT=8006&TRM=ISN%3A0000000122591313&TERMS_OF_USE_AGREED=Y&terms_of_use_agree=send',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb12629498q',
#   'Titre': 'Songe énigmatique sur la peinture universelle',
#   'pubPlace': 'Toulouse',
#   'Editeur': 'Arnaud Colomiez',
#   'Date': '1658',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb310486347',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k1118908',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Structuration',
#   'Anaïs Mazoué': 'Balisage, Indexation',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': 'Transcription, Correction',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Indexation',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + preface) + body (livre L1)'},
#  {'Nom': 'Monier',
#   'Prenom': 'Pierre',
#   'ISNI': 'https://isni.org/isni/0000000121263908',
#   'DBI/ARK': 'https://data.bnf.fr/ark:/12148/cb12195679m',
#   'Titre': 'Histoire des arts qui ont rapport au dessein',
#   'pubPlace': 'Paris',
#   'Editeur': 'Pierre Giffart',
#   'Date': '1698',
#   'USTC': 'https://www.ustc.ac.uk/editions/3131573',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k74873s',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': 'Correction, Structuration, Balisage, Indexation',
#   'Teklia': 'Transcription, Structuration',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': 'Identification des œuvres',
#   'Carla Tricon': 'Identification des œuvres, Indexation',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + lettre + preface + dedicace) + body (3 livres L avec chapitres C)'},
#  {'Nom': 'Daret',
#   'Prenom': 'Pierre',
#   'ISNI': 'https://isni.oclc.org/cbs/DB=1.2/CMD?ACT=SRCH&IKT=8006&TRM=ISN%3A0000000121202494&TERMS_OF_USE_AGREED=Y&terms_of_use_agree=send',
#   'DBI/ARK': 'https://data.bnf.fr/ark:/12148/cb12259347g',
#   'Titre': 'Abregé de la vie de Raphaël Sansio d\'Urbin, tres-excellent peintre & architecte ; ou il est traitté de ses oeuvres, des stampes qui en ont esté gravées, tant par Marc-Antoine Bolognois qu\'autres excellent ["sic"] graveurs',
#   'pubPlace': 'Paris',
#   'Editeur': "Chez l'auteur",
#   'Date': '1651',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb31545604f',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k1503469p',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': 'Correction, Balisage, Indexation',
#   'Teklia': 'Transcription, Structuration',
#   'Hippolyte Faré': 'Correction',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': 'Correction, Identification des œuvres',
#   'Carla Tricon': 'Identification des œuvres, Indexation',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + preface) + body (2 chapitres)'},
#  {'Nom': 'Dupuy du Grez',
#   'Prenom': 'Bernard',
#   'ISNI': 'https://isni.org/isni/0000000122704314',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb13011007f',
#   'Titre': 'Traité sur la peinture pour apprendre la teorie et se perfectionner dans la pratique',
#   'pubPlace': 'Toulouse',
#   'Editeur': 'Veuve de J. Pech & A. Pech',
#   'Date': '1699',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb30383816v',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k111861m',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Correction, Structuration, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': 'Transcription, Correction, Balisage',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + preface + avertissement + privilege + errata) + body (4 livres avec C1 dissertation et C2 supplément à la dissertation) + back (table des matieres)'},
#  {'Nom': 'Piles (de)',
#   'Prenom': 'Roger',
#   'ISNI': 'https://isni.org/isni/0000000083425581',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb11998742h',
#   'Titre': 'Dialogue sur le coloris',
#   'pubPlace': 'Paris',
#   'Editeur': 'Nicolas Langlois / Antoine Lambin',
#   'Date': '1699',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb31112328k',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k111107n/f1.item',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': 'Correction, Structuration, Balisage, Indexation',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage) + body (1 livre)'},
#  {'Nom': 'Piles (de)',
#   'Prenom': 'Roger',
#   'ISNI': 'https://isni.org/isni/0000000083425581',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb11998742h',
#   'Titre': 'Cours de Peinture par Principes',
#   'pubPlace': 'Paris',
#   'Editeur': 'Charles-Antoine Jombert',
#   'Date': '1708',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb311123215',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k5814705x?rk=21459;2',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Transcription, Correction, Structuration, Balisage, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': 'Correction, Identification des œuvres',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage) + body (18 chapitres)'},
#  {'Nom': 'Piles (de)',
#   'Prenom': 'Roger',
#   'ISNI': 'https://isni.org/isni/0000000083425581',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb11998742h',
#   'Titre': "Conversations sur la connoissance de la peinture, et sur le jugement qu'on doit faire des tableaux. Où par occasion il est parlé de la vie de Rubens, et de quelques-uns de ses plus beaux Ouvrages.",
#   'pubPlace': 'Paris',
#   'Editeur': 'Nicolas Langlois',
#   'Date': '1677',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb31112320t',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k65173190?rk=42918;4',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Transcription, Correction, Structuration, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': 'Balisage',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + preface) + body (2 livres) + back (privilege)'},
#  {'Nom': 'Piles (de)',
#   'Prenom': 'Roger',
#   'ISNI': 'https://isni.org/isni/0000000083425581',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb11998742h',
#   'Titre': 'Abregé de la vie des peintres, Avec des reflexions sur leurs Ouvrages, Et un Traité du Peintre parfait, de la connoissance des Desseins, et de l’utilité des Estampes.',
#   'pubPlace': 'Paris',
#   'Editeur': 'François Muguet',
#   'Date': '1699',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb31112316k',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k6568782t.r',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Correction, Structuration, Balisage, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': 'Transcription, Structuration',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Identification des œuvres',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + preface) + body (7 livres [L1 = idée du peintre, à partir de C30 = abregé vie des peintres] 255 chapitres au total)'},
#  {'Nom': 'Lomazzo/Pader',
#   'Prenom': 'Hilaire',
#   'ISNI': 'https://isni.org/isni/0000000121427781; https://isni.oclc.org/cbs/DB=1.2/CMD?ACT=SRCH&IKT=8006&TRM=ISN%3A0000000122591313&TERMS_OF_USE_AGREED=Y&terms_of_use_agree=send',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb12358011k; https://data.bnf.fr/fr/ark:/12148/cb12629498q',
#   'Titre': "Traicté de la proportion naturelle et artificielle des choses par Jean Pol Lomazzo [...] traduit d'italien en français par Hilaire Pader",
#   'pubPlace': 'Toulouse',
#   'Editeur': 'Arnaud Colomiez',
#   'Date': '1649',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb30829064k',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/btv1b86266498',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': 'Correction, Structuration, Balisage, Indexation',
#   'Teklia': 'Transcription',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + lettre + preface + avertissement + eloge + biographie + preface) + body (L1 [32 chapitres])'},
#  {'Nom': 'Da Vinci',
#   'Prenom': 'Leonardo',
#   'ISNI': 'https://isni.oclc.org/cbs/DB=1.2/SET=12/TTL=1/SHW?FRST=3',
#   'DBI/ARK': 'https://data.bnf.fr/ark:/12148/cb11912491s',
#   'Titre': "Trattato della pittura novamente dato in luce, con la vita dell'istesso autore, scritta da Rafaelle du Fresne, si sono giunti i tre libri della pittura, et il trattato della statua di Leon Battista Alberti, con la vita del medesimo",
#   'pubPlace': 'Paris',
#   'Editeur': 'Jacques Langlois',
#   'Date': '1651',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb39316381f',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k134521m#',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': 'Balisage, Indexation',
#   'Alessia Avena': '',
#   'Youssouf Diawara': 'Transcription, Structuration [Flora Belin, Maxine Schoehuys-Kreiss]',
#   'Julia Castiglione': '',
#   'Anna Sconza': 'Correction',
#   'Irene Calcagno': 'Correction, Structuration, Balisage, Indexation',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': 'Correction, Identification des œuvres',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + lettres + biographie + avis) + body (365 chapitres dans un livre L1) + back (lettre, biographie, postface)'},
#  {'Nom': '10/0302024',
#   'Prenom': 'De Vinci',
#   'ISNI': 'Léonard',
#   'DBI/ARK': 'https://isni.oclc.org/cbs/DB=1.2/SET=12/TTL=1/SHW?FRST=3',
#   'Titre': 'https://data.bnf.fr/fr/ark:/12148/cb11912491s',
#   'pubPlace': "Traitté de la peinture de Léonard de Vinci donné au public et traduit d'Italien en françois par R.F. S. D.C.",
#   'Editeur': 'Paris',
#   'Date': 'Jacques Langlois',
#   'USTC': '1651',
#   'Bibliotheque': 'https://catalogue.bnf.fr/ark:/12148/cb31588107n',
#   'PaysCons': 'Bibliothèque nationale de France',
#   'VilleCons': 'France',
#   'LienReproduction': 'Paris',
#   'Droits': 'https://gallica.bnf.fr/ark:/12148/btv1b86207616.r=Traitt%C3%A9%20de%20la%20peinture%20de%20L%C3%A9onard%20de%20Vinci%20donn%C3%A9%20au%20public%20et%20traduit%20d%27Italien%20en%20fran%C3%A7ois%20par%20R.F.%20S.%20D.C.?rk=21459;2',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': 'Transcription, Structuration [Flora Belin, Maxine Schoehuys-Kreiss]',
#   'Anna Sconza': '',
#   'Irene Calcagno': 'Correction',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Bassi',
#   'Prenom': 'Martino',
#   'ISNI': 'https://isni.org/page/search-database/',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb102995049',
#   'Titre': "Dispareri in materia d'architettura e prospettiva",
#   'pubPlace': 'Brescia',
#   'Editeur': 'Francesco et Pietro Maria Marchetti (frères)',
#   'Date': '1572',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb300645526',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bd6t57781345.r=dispareri%20in%20materia%20d%27architettura?rk=21459;2',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': 'Transcription, Correction, Structuration, Balisage, Indexation',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': 'Correction, Balisage, Indexation, Identification des œuvres',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage) + body (L1 avec 10 lettres)'},
#  {'Nom': 'Agucchi',
#   'Prenom': 'Giovan Battista',
#   'ISNI': 'https://isni.org/isni/000000006127302X',
#   'DBI/ARK': 'https://www.treccani.it/enciclopedia/giovanni-battista-agucchi_(Dizionario-Biografico)/',
#   'Titre': '"Trattato della pittura" in Annibale Carracci, Diverse figure al numero di ottanta, disegnate di penna nell\'hore di ricreatione, intagliate in rame e cavate dagli originali da Simone Giulino, stampatore parigino (p.3-21)',
#   'pubPlace': 'Rome',
#   'Editeur': 'Ludovico Grignani',
#   'Date': '1646',
#   'USTC': 'https://www.ustc.ac.uk/editions/4048211',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/btv1b8454358x.item',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': 'Transcription, Structuration',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': 'Correction, Balisage',
#   'Corto Rolaz': '',
#   'Octave Philibert': 'Indexation',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': 'Correction, Identification des œuvres',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage) + body (lettre + p. 23 à 104 = figure)'},
#  {'Nom': 'Pader',
#   'Prenom': 'Hilaire',
#   'ISNI': 'https://isni.oclc.org/cbs/DB=1.2/CMD?ACT=SRCH&IKT=8006&TRM=ISN%3A0000000122591313&TERMS_OF_USE_AGREED=Y&terms_of_use_agree=send',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb12629498q',
#   'Titre': 'La peinture parlante',
#   'pubPlace': 'Toulouse',
#   'Editeur': 'Arnaud Colomiez',
#   'Date': '1653',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb310486316',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k6570462t/f5.item',
#   'Droits': 'Gallica, Bibliothèque nationale de France',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': 'Correction, Balisage, Indexation',
#   'Teklia': 'Transcription, Structuration',
#   'Hippolyte Faré': 'Correction, Balisage',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': 'Correction, Identification des œuvres',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + preface + lexique + avis +poeme + lettre + privilege + eloge) + body (L1 + lettre)'},
#  {'Nom': 'Bellori',
#   'Prenom': 'Giovanni Pietro',
#   'ISNI': 'http://isni.org/isni/0000000114785193',
#   'DBI/ARK': 'http://ark.bnf.fr/ark:/12148/cb121957985',
#   'Titre': "Le vite de' pittori, scultori et architetti moderni",
#   'pubPlace': 'Rome',
#   'Editeur': 'al Mascardi',
#   'Date': '1672',
#   'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb169752880',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k851200q',
#   'Droits': 'ATIR',
#   'Emma Bondoerffer': 'Structuration',
#   'Anaïs Mazoué': 'Balisage, Indexation',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + dedicace + lettre + eloge + table des matieres) + body (13 chapitres)'},
#  {'Nom': 'Alberti',
#   'Prenom': 'Leon Battista',
#   'ISNI': 'http://isni.org/isni/0000000120958329',
#   'DBI/ARK': '',
#   'Titre': 'La Pittura di Leon Battista Alberti, tradotta per M. Lodovico Domenichi',
#   'pubPlace': 'Venise',
#   'Editeur': 'G. Giolito de Ferrari',
#   'Date': '1547',
#   'USTC': 'https://www.ustc.ac.uk/editions/808304',
#   'Bibliotheque': 'Getty Institute',
#   'PaysCons': '',
#   'VilleCons': '',
#   'LienReproduction': 'https://archive.org/details/gri_pitturexxxxx00albe',
#   'Droits': '',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
# ...
#   'pubPlace': 'Venise',
#   'Editeur': 'G. Giolito di Ferrarii',
#   'Date': '1549',
#   'USTC': 'https://www.ustc.ac.uk/editions/827607',
#   'Bibliotheque': 'Getty Institute',
#   'PaysCons': 'USA',
#   'VilleCons': 'Los Angeles',
#   'LienReproduction': 'https://archive.org/details/deldonipatitoinp00doni',
#   'Droits': '',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': 'Indexation',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': 'Correction, Structuration, Balisage',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': 'Transcription',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Barbaro',
#   'Prenom': 'Daniele',
#   'ISNI': '',
#   'DBI/ARK': 'https://catalogue.bnf.fr/ark:/12148/cb39315875n48z',
#   'Titre': "La pratica della perspettiva di Monsignor Daniel Barbaro eletto patriarca d'Aquileia, opera molto utile a pittori, a scultori, & ad architetti. Con due tavole, una de'capitoli principali, l'altra delle cose più notabili contenute nella presente opera.",
#   'pubPlace': 'Venise',
#   'Editeur': 'Camillo et Rutilio Borgominieri',
#   'Date': '1569',
#   'USTC': 'https://www.ustc.ac.uk/editions/812217',
#   'Bibliotheque': 'Getty Institute',
#   'PaysCons': '',
#   'VilleCons': '',
#   'LienReproduction': 'https://archive.org/details/gri_33125008285765/page/n3/mode/2up',
#   'Droits': '',
#   'Emma Bondoerffer': 'Transcription, Structuration',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': 'Correction, Balisage, Indexation',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage, dedicace, preface), body (9 livres [L1: 9Chap, L2 : 11C, L3: 33C, L4: 18C, L5: 3C, L6: 4C, L7: 2C, L8: 4C, L9: 5C], back (postface, gap)'},
#  {'Nom': 'Borghini',
#   'Prenom': 'Raffaello',
#   'ISNI': 'https://isni.org/isni/0000000081356930',
#   'DBI/ARK': 'https://catalogue.bnf.fr/ark:/12148/cb12463031c',
#   'Titre': 'Il Riposo',
#   'pubPlace': 'Florence',
#   'Editeur': 'Giorgio Marescotti',
#   'Date': '1584',
#   'USTC': 'https://www.ustc.ac.uk/editions/816377',
#   'Bibliotheque': '',
#   'PaysCons': '',
#   'VilleCons': '',
#   'LienReproduction': '',
#   'Droits': 'ATIR',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': 'Structuration, Indexation',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': 'Transcription',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Accolti',
#   'Prenom': 'Pietro',
#   'ISNI': 'https://isni.org/isni/0000000115787350',
#   'DBI/ARK': 'http://ark.bnf.fr/ark:/12148/cb30002033t',
#   'Titre': "Lo inganno de gl'occhi : prospettiva pratica",
#   'pubPlace': 'Florence',
#   'Editeur': 'P. Cecconcelli',
#   'Date': '1625',
#   'USTC': 'https://www.ustc.ac.uk/editions/4008330',
#   'Bibliotheque': 'Getty Institute',
#   'PaysCons': '',
#   'VilleCons': '',
#   'LienReproduction': 'https://archive.org/details/loingannodeglocc00acco/page/n3/mode/2up',
#   'Droits': '',
#   'Emma Bondoerffer': 'Transcription, Structuration',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': 'Correction, Structuration, Balisage, Indexation',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Indexation',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage, dedicate, eloge x2, avis), body (3div1 [38 div2 ; 20 div2 ; 31 div2]'},
#  {'Nom': 'Ottonelli',
#   'Prenom': 'Giovanni',
#   'ISNI': 'https://isni.oclc.org/cbs/DB=1.2/SET=5/TTL=1/SHW?FRST=1',
#   'DBI/ARK': 'ark:/13960/t6252zw56',
#   'Titre': 'Trattato della pittura e sculptura, uso e abuso loro',
#   'pubPlace': 'Florence',
#   'Editeur': 'Bonardi',
#   'Date': '1652',
#   'USTC': 'https://www.ustc.ac.uk/editions/1726303',
#   'Bibliotheque': 'Getty Institute',
#   'PaysCons': '',
#   'VilleCons': 'Los Angeles',
#   'LienReproduction': 'https://archive.org/details/trattatodellapit00otto/page/n3/mode/2up',
#   'Droits': 'Public domain',
#   'Emma Bondoerffer': 'Transcription, Structuration, Balisage',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Sambin',
#   'Prenom': 'Hugues',
#   'ISNI': 'https://isni.oclc.org/cbs/DB=1.2/SET=1/TTL=1/CMD?ACT=SRCH&IKT=8006&SRT=LST_nd&TRM=Huges+sambin',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb12144720z',
#   'Titre': 'Œuvre de la diversité des termes dont on use en architecture, reduict en ordre par maistre',
#   'pubPlace': 'Lyon',
#   'Editeur': 'Jean Marcorelle et Jean Durand',
#   'Date': '1572',
#   'USTC': 'https://www.ustc.ac.uk/editions/24496',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k79300d?rk=21459;2',
#   'Droits': 'Public domain',
#   'Emma Bondoerffer': 'Transcription, Structuration',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': 'Correction, Balisage',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Vignola, Barozzi da',
#   'Prenom': 'Jacopo',
#   'ISNI': 'https://isni.oclc.org/cbs/DB=1.2/SET=3/TTL=1/SHW?FRST=1',
#   'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb120950564',
#   'Titre': 'Le due regole della prospettiva pratica',
#   'pubPlace': 'Rome',
#   'Editeur': 'Francesco Zannetti',
#   'Date': '1583',
#   'USTC': 'https://www.ustc.ac.uk/editions/807538',
#   'Bibliotheque': '',
#   'PaysCons': '',
#   'VilleCons': 'ATIR',
#   'LienReproduction': 'https://drive.google.com/file/d/1dXqThEybRdaQ_wf2jkwmVgm-UGR8c_am/view?usp=share_link',
#   'Droits': '',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': 'Transcription',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Palladio',
#   'Prenom': 'Andrea',
#   'ISNI': 'https://isni.org/isni/0000000121222209',
#   'DBI/ARK': 'ark:/12148/cb119184708',
#   'Titre': 'Les quatre livres de l’architecture d’André Palladio traduit par R. Fréart de Chambray',
#   'pubPlace': 'Paris',
#   'Editeur': 'Edme Martin',
#   'Date': '1650',
#   'USTC': 'https://www.ustc.ac.uk/editions/6006478',
#   'Bibliotheque': 'CESR',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris, Tours',
#   'LienReproduction': 'https://architectura.univ-tours.fr/livres-consultation/cesr_4045consult/?fiche=1',
#   'Droits': '© 2004 – CESR ARCHITECTURA',
#   'Emma Bondoerffer': 'Transcription',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Huret',
#   'Prenom': 'Grégoire',
#   'ISNI': 'https://isni.oclc.org/cbs/DB=1.2/SET=8/TTL=1/SHW?FRST=2',
#   'DBI/ARK': 'ark:/12148/cb306298335',
#   'Titre': "Optique de portraiture et de peinture, Paris, chez l'auteur",
#   'pubPlace': 'Paris',
#   'Editeur': "Chez l'Auteur",
#   'Date': '1670',
#   'USTC': 'https://www.ustc.ac.uk/editions/6123137',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/btv1b8612087c',
#   'Droits': 'Public domain',
#   'Emma Bondoerffer': 'Transcription',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Identification des œuvres',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Palladio',
#   'Prenom': 'Andrea',
#   'ISNI': 'https://isni.org/isni/0000000121222209',
#   'DBI/ARK': 'ark:/12148/cb119184708',
#   'Titre': 'I quattro libri dell’architettura di Andrea Palladio. Ne’quali, dopo un breve trattato de’cinque ordini, e di quelli avertimenti, che sono piu necessarii nel fabricare, si tratta delle case private, delle vie, dei ponti, delle piazze, dei xisti et de’ tempii. Con privilegi.',
#   'pubPlace': 'Venise',
#   'Editeur': 'Dominico de’Franceschi',
#   'Date': '1570',
#   'USTC': 'http://catalogue.bnf.fr/ark:/12148/cb119409036',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k322764c',
#   'Droits': 'Source gallica.bnf.fr / Bibliothèque national de France',
#   'Emma Bondoerffer': 'Transcription, Structuration',
#   'Anaïs Mazoué': 'Transcription',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': 'Transcription',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': 'Correction, Balisage, Indexation, Identification des œuvres',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Bartoli',
#   'Prenom': 'Cosimo',
#   'ISNI': 'ISNI 0000 0001 2281 1371',
#   'DBI/ARK': 'ark:/12148/cb125520809',
#   'Titre': 'Ragionamenti Accademici sopra alcuni luoghi difficili di Dante',
#   'pubPlace': 'Venezia',
#   'Editeur': "Francesco de' Franceschi Senese",
#   'Date': '1567',
#   'USTC': 'https://www.ustc.ac.uk/editions/812413',
#   'Bibliotheque': 'Library of the University of Toronto',
#   'PaysCons': 'Canada',
#   'VilleCons': 'Toronto',
#   'LienReproduction': 'https://archive.org/details/ragionamentiacca00bart/page/n3/mode/2up',
#   'Droits': 'Public domain',
#   'Emma Bondoerffer': '',
#   'Anaïs Mazoué': 'Transcription, Structuration',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': 'Correction, Balisage, Indexation',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Identification des œuvres',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Accolti',
#   'Prenom': 'Pietro',
#   'ISNI': 'ISNI 0000 0003 9924 5763',
#   'DBI/ARK': 'ark:/12148/cb16708799z',
#   'Titre': 'Lo inganno degli occhi: prospettiva pratica',
#   'pubPlace': 'Firenze',
#   'Editeur': 'Pietro Cecconcelli',
#   'Date': '1625',
#   'USTC': 'https://www.ustc.ac.uk/editions/4008330',
#   'Bibliotheque': 'Getty Research Institute',
#   'PaysCons': 'USA',
#   'VilleCons': 'Los Angeles',
#   'LienReproduction': 'https://archive.org/details/loingannodeglocc00acco/page/n3/mode/2up',
#   'Droits': 'Public domain',
#   'Emma Bondoerffer': 'Transcription, Structuration, Balisage, Indexation',
#   'Anaïs Mazoué': '',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': ''},
#  {'Nom': 'Bellori',
#   'Prenom': 'Giovanni Pietro',
#   'ISNI': 'http://isni.org/isni/0000000114785194',
#   'DBI/ARK': 'http://ark.bnf.fr/ark:/12148/cb121957986',
#   'Titre': "Descrizzione delle imagini dipinte da Rafaelle d'Urbino nelle camere del palazzo apostolico Vaticano , di Gio. Pietro Bellori...",
#   'pubPlace': 'Rome',
#   'Editeur': 'G. G. Komarek',
#   'Date': '1695',
#   'USTC': 'http://catalogue.bnf.fr/ark:/12148/cb300811089',
#   'Bibliotheque': 'Bibliothèque nationale de France',
#   'PaysCons': 'France',
#   'VilleCons': 'Paris',
#   'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k1118531?rk=42918;4',
#   'Droits': 'ATIR',
#   'Emma Bondoerffer': 'Structuration',
#   'Anaïs Mazoué': 'Balisage, Indexation',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': '',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + lettre + Imprimatur [note] + errata) + body (2 chapitres avec sous chapitres)'},
#  {'Nom': 'Bartoli',
#   'Prenom': 'Cosimo',
#   'ISNI': 'http://isni.org/isni/0000000122811371',
#   'DBI/ARK': 'http://ark.bnf.fr/ark:/12148/cb125520809',
#   'Titre': "L'architettura tradotta in lingua fiorentina da Cosimo Bartoli, con la aggiunta de disegni",
#   'pubPlace': 'Florence',
#   'Editeur': 'Lorenzo Torrentino',
#   'Date': '1550',
#   'USTC': 'https://www.ustc.ac.uk/editions/808305',
#   'Bibliotheque': '',
#   'PaysCons': '',
#   'VilleCons': '',
#   'LienReproduction': 'https://books.google.at/books?id=B_1OAAAAcAAJ&hl=fr&source=gbs_book_other_versions',
#   'Droits': 'ATIR',
#   'Emma Bondoerffer': 'Structuration',
#   'Anaïs Mazoué': 'Balisage, Indexation',
#   'Teklia': '',
#   'Hippolyte Faré': '',
#   'Corto Rolaz': '',
#   'Octave Philibert': '',
#   'Alessia Avena': '',
#   'Youssouf Diawara': '',
#   'Julia Castiglione': '',
#   'Anna Sconza': '',
#   'Irene Calcagno': '',
#   'Memofonte': '',
#   'ATIR': '',
#   'Pierre Husson': '',
#   'Carla Tricon': 'Identification des œuvres',
#   'Nicolò Zanolli': '',
#   'Elisa Bonaiuti': '',
#   'NiveauTranscription': 'édition complète',
#   'SpecificitesXML': '',
#   'StructureXML': 'front (titlePage + lettre + preface) + body (10 livres avec chapitres)'}]

# %% [markdown]
# ## Générer le header

# %%
def generer_header(fichier_header, fichier_sortie): # définition de la fonction qui génère les headers
    header = lire_csv_header(fichier_header) # Utilise la liste créée avec les infos du csv

    teiHeader = ET.Element("listHeaders")
    for info in header : # Pour chaque ligne du csv, chaque élément de la liste, on fait un header tel que
        root = ET.SubElement(teiHeader, "teiHeader") # racine du XML 

# construction du XML en partant de la racine, enr ajoutant les éléments du header, les attributs et le contenu récupéré dans le CSV
        fileDesc_elem = ET.SubElement(root, "fileDesc") 
        titleStmt_elem = ET.SubElement(fileDesc_elem, "titleStmt")
        title_elem = ET.SubElement(titleStmt_elem, "title", attrib={"xml:lang": "fra"})
        title_elem.text = info["Titre"]
        
        for key in list(info.keys())[14:30] : # pour les dernières lignes (attribution des resp) on fait une boucle pour que 
            # si le contenenu est non-vide on crée une entrée dans le header en utilisant le nom de la colonne et le contenu pour donner la resp.
            if info[key] != '' :
                respStmt_elem = ET.SubElement(titleStmt_elem, "respStmt")
                name_elem = ET.SubElement(respStmt_elem, "name")
                name_elem.text = key
                resp_elem = ET.SubElement(respStmt_elem, "resp")
                resp_elem.text = info[key]
                

        editionStmt_elem = ET.SubElement(fileDesc_elem, "editionStmt")
        edition_elem = ET.SubElement(editionStmt_elem, "edition")
        edition_elem.text = "Edition numérique réalisée dans le cadre du projet ANR ArTerm."
        
        publicationStmt_elem = ET.SubElement(fileDesc_elem, "publicationStmt")
        publisher_elemPubli = ET.SubElement(publicationStmt_elem, "publisher")
        publisher_elemPubli.text = "ArTerm"
        pubPlace_elemPubli = ET.SubElement(publicationStmt_elem, "pubPlace")
        pubPlace_elemPubli.text = "Paris"
        date_elemPubli = ET.SubElement(publicationStmt_elem, "date", attrib={"when": "2028"})
        date_elemPubli.text = "2028"
        availability_elem = ET.SubElement(publicationStmt_elem, "availability")
        licence_elem = ET.SubElement(availability_elem, "licence", target="https://creativecommons.org/licenses/by-nc-sa/4.0/")
        licence_elem.text = "ArTerm Copora © 2028 by ArTerm ANR is licensed under CC BY-NC-SA 4.0."

        sourceDesc_elem = ET.SubElement(fileDesc_elem, "sourceDesc")
        
        bibl_elem = ET.SubElement(sourceDesc_elem, "bibl", attrib={"source": info["LienReproduction"]})
        author_elem = ET.SubElement(bibl_elem, "author", attrib={"ref": info["DBI/ARK"]})
        author_elem.text = info["Prenom"] and info["Nom"]
        isni_elem = ET.SubElement(author_elem, "idno", attrib={"type":"ISNI"})
        isni_elem.text = info["ISNI"]
        title_elemSource = ET.SubElement(bibl_elem, "title", attrib={"xml:lang": "fra"})
        title_elemSource.text = info["Titre"]
        publisher_elem = ET.SubElement(bibl_elem, "publisher")
        publisher_elem.text = info["Editeur"]
        pubPlace_elem = ET.SubElement(bibl_elem, "pubPlace")
        pubPlace_elem.text = info["pubPlace"]
        date_elem = ET.SubElement(bibl_elem, "date", attrib={"when": info["Date"]})
        date_elem.text = info["Date"]
        bibl_elem.text = info["Droits"]        
        
        msDesc_elem = ET.SubElement(sourceDesc_elem, "msDesc")
        msId_elem = ET.SubElement(msDesc_elem, "msIdentifier")
        country_elem = ET.SubElement(msId_elem, "country")
        country_elem.text = info["PaysCons"] 
        settlement_elem = ET.SubElement(msId_elem, "settlement", attrib={"ref": f"#{info['VilleCons']}"})
        settlement_elem.text = info["VilleCons"] 
        institution_elem = ET.SubElement(msId_elem, "institution")
        institution_elem.text = info["Bibliotheque"] 
        repository_elem =ET.SubElement(msId_elem, "repository")
        idno_elem =ET.SubElement(msId_elem, "idno", attrib={"type":"USTC"})
        idno_elem.text = info["USTC"]
        
        xi_elem = ET.SubElement(sourceDesc_elem, "xi:include", href="../IndexOeuvres.xml", xpointer="element(/1/1)")

        encodingDesc_elem = ET.SubElement(root, "encodingDesc")
        projectDesc_elem = ET.SubElement(encodingDesc_elem, "projectDesc")
        p_projectDesc_elem = ET.SubElement(projectDesc_elem, "p")
        p_projectDesc_elem.text = "Le projet ArTerm propose l\'édition numérique d\'un corpus franco-italien de textes de la littérature artistique (XVIe-XVIIe s.), afin d\'examiner les phénomènes de traduction des théories des arts d\'une langue à l\'autre et des transferts linguistiques du lexique esthétique et technique, à l\'aide d\'un Glossaire franco-italien du patrimoine artistique."
        editorialDecl_elem = ET.SubElement(encodingDesc_elem, "editorialDecl")
        correction_elem = ET.SubElement(editorialDecl_elem, "correction", attrib={"status": "medium", "method": "silent"})
        p_correction_elem = ET.SubElement(correction_elem, "p")
        p_correction_elem.text = info["NiveauTranscription"]
        normalization_elem = ET.SubElement(editorialDecl_elem, "normalization", attrib={"method":"silent"})
        p_normalization_elem = ET.SubElement(normalization_elem, "p")
        p_normalization_elem.text = "Les ambiguïtés entre i, j, u, v ont été corrigées ; les espaces autour des ponctuations et accentuations ont été normalisées en suivant les règles de typographies du 20è siècle."
        punctuation_elem = ET.SubElement(editorialDecl_elem, "punctuation", attrib={"marks":"some"})
        p_punctuation_elem = ET.SubElement(punctuation_elem, "p")
        p_punctuation_elem.text = "En français, les point-virgules ont souvent été transformés en virgules ou en point, le reste des ponctuations ont été conservées comme dans les imprimés de référence. En italien, les ponctuations ont pu être retravaillées pour fluidifier la lecture."
        segmentation_elem = ET.SubElement(editorialDecl_elem, "segmentation")
        p_segmentation_elem = ET.SubElement(segmentation_elem, "p")
        p_segmentation_elem.text = "Les paragraphes sont indiqués dans des balises p, enfant de balises div/div1/div2/div3/div4. Structure de ce fichier : " + info["StructureXML"] #Ajouter la phrase générique
        hyphen_elem = ET.SubElement(editorialDecl_elem, "hyphenation", attrib={"eol":"none"})
        stdVals_elem = ET.SubElement(editorialDecl_elem, "stdVals")
        p_stdVals_elem = ET.SubElement(stdVals_elem, "p")
        p_stdVals_elem.text = "Norme ISO-8601 pour les dates"
        p_encoding_elem = ET.SubElement(encodingDesc_elem, "p")
        p_encoding_elem.text = info["SpecificitesXML"]

        profileDesc_elem = ET.SubElement(root, "profileDesc")
        xi_elem = ET.SubElement(profileDesc_elem, "xi:include", href="../IndexPersonnes.xml", xpointer="element(/1/1)")
        xi_elem = ET.SubElement(profileDesc_elem, "xi:include", href="../IndexLieux.xml", xpointer="element(/1/1)")

#Générer les headers
    tree = ET.ElementTree(teiHeader) # création de l'arbre XML
    ET.indent(tree, space="  ", level=0)  # Indentation auto pour une sortie lisible (ici 2 espaces, peut être modifié)
    tree.write(fichier_sortie, encoding="utf-8", xml_declaration=True) # écriture du fichier XML de sortie

    print(f"Header généré avec succès : {fichier_sortie}")

# %% [markdown]
# ## Appel de la fonction generer_header()
#
# Les deux données attendues par cette fonction sont un fichier d'entrée (`header.csv`) qui ne bouge pas, et un fichier de sortie dont le nom peut être modifié si besoin.

# %%
generer_header("header.csv", "outputheader.xml")
# Out:
# Ligne ignorée (champs manquants) : {'NomAuteur': 'Borghini', 'PrenomAuteur': 'Raffaele', 'FicheISNI': '', 'DBI/ARK': '', 'TitreOuvrage': '', 'LieuEdition': '', 'Editeur': '', 'Date': '', 'USTC': '', 'BiblioConservation': '', 'PaysConservation': '', 'VilleConservation': '', 'LienReproduction': '', 'Droits': '', 'EditionsModernes': '', 'Traductions': '', 'BibliographieSelective': 'Pascal Dubourg-Glatigny, "La question de la perspective matérielle dans les traités du Cinquecento", dans L\'artiste et l\'oeuvre à l\'épreuve de la perspective, dir. Marianne Cojannot-Le Blanc, Marisa Dalai Emiliani et Pascal Dubourg Glatigny, Rome, EFR, 2006, p. 365-384', 'Licence': '', 'ContributeursEmmaBondoerffer': '', 'ContributeursAnaïsMazoué': '', 'ContributeursTeklia': '', 'ContributeursHippolyteFaré': '', 'ContributeursCortoRolaz': '', 'ContributeursOctavePhilibert': '', 'ContributeursAlessiaAvena': '', 'ContributeursYoussoufDiawara': '', 'ContributeursJuliaCastiglione': '', 'ContributeursAnnaSconza': '', 'ContributeursIreneCalcagno': '', 'ContributeursMemofonte': '', 'ContributeursATIR': '', 'ContributeursPierreHusson': '', 'ContributeursCarlaTricon': '', 'ContributeursNicolòZanolli': '', 'ContributeursElisaBonaiuti': '', 'NiveauTranscription': '', 'SpecificitesDuXML': '', 'StructureFichierXML': '', None: ['', '', '', '', '']}
# [{'Nom': 'Bosse', 'Prenom': 'Abraham', 'ISNI': 'http://isni.org/isni/0000000121355423', 'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb118930604', 'Titre': "Sentimens sur la distinction des diverses manieres de peinture, dessein & graveure, & des originaux d'avec leurs copies. Ensemble du choix des sujets, & des chemins pour arriver facilement & promptement à bien pourtraire.", 'pubPlace': 'Paris', 'Editeur': 'Pierre Des Hayes', 'Date': '1649', 'USTC': 'http://catalogue.bnf.fr/ark:/12148/cb30134732p', 'Bibliotheque': 'Bibliothèque nationale de France', 'PaysCons': 'France', 'VilleCons': 'Paris', 'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/btv1b8612040z', 'Droits': 'Gallica, Bibliothèque nationale de France', 'Emma Bondoerffer': 'Transcription, Balisage, Indexation', 'Anaïs Mazoué': '', 'Teklia': '', 'Hippolyte Faré': '', 'Corto Rolaz': '', 'Octave Philibert': '', 'Alessia Avena': '', 'Youssouf Diawara': '', 'Julia Castiglione': '', 'Anna Sconza': '', 'Irene Calcagno': '', 'Memofonte': '', 'ATIR': '', 'Pierre Husson': '', 'Carla Tricon': 'Identification des œuvres', 'Nicolò Zanolli': '', 'Elisa Bonaiuti': '', 'NiveauTranscription': 'édition complète', 'SpecificitesXML': '', 'StructureXML': 'body avec div des heading Transkribus'}, {'Nom': 'Bosse', 'Prenom': 'Abraham', 'ISNI': 'http://isni.org/isni/0000000121355424', 'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb118930604', 'Titre': "Traité des pratiques géométrales et perspective enseignée dans l'Académie royale de peinture et scupture", 'pubPlace': 'Paris', 'Editeur': 'Antoine Cellier', 'Date': '1665', 'USTC': 'http://catalogue.bnf.fr/ark:/12148/cb30134737d', 'Bibliotheque': 'Bibliothèque nationale de France', 'PaysCons': 'France', 'VilleCons': 'Paris', 'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/bpt6k1083747', 'Droits': 'Gallica, Bibliothèque nationale de France', 'Emma Bondoerffer': 'Transcription, Balisage, Indexation', 'Anaïs Mazoué': '', 'Teklia': '', 'Hippolyte Faré': '', 'Corto Rolaz': '', 'Octave Philibert': '', 'Alessia Avena': '', 'Youssouf Diawara': '', 'Julia Castiglione': '', 'Anna Sconza': '', 'Irene Calcagno': '', 'Memofonte': '', 'ATIR': '', 'Pierre Husson': '', 'Carla Tricon': 'Identification des œuvres', 'Nicolò Zanolli': '', 'Elisa Bonaiuti': '', 'NiveauTranscription': 'édition complète', 'SpecificitesXML': '', 'StructureXML': 'body avec div des heading Transkribus'}, {'Nom': 'Bosse', 'Prenom': 'Abraham', 'ISNI': 'http://isni.org/isni/0000000121355425', 'DBI/ARK': 'https://data.bnf.fr/fr/ark:/12148/cb118930604', 'Titre': "Traicté des manieres de graver en taille douce sur l'airin . Par le Moyen des Eauxs Fortes, & des Vernix Durs & Mols. Ensemble de la façon d'en Imprimer les Planches, & d'en Construire la Presse, & autres choses concernans lesdits Arts.", 'pubPlace': 'Paris', 'Editeur': "chez ledit Bosse, en l'Isle du Palais, à la Rozerouge, devant la Megisserie", 'Date': '1645', 'USTC': 'https://catalogue.bnf.fr/ark:/12148/cb40021779b', 'Bibliotheque': 'Bibliothèque nationale de France', 'PaysCons': 'France', 'VilleCons': 'Paris', 'LienReproduction': 'https://gallica.bnf.fr/ark:/12148/btv1b8626172s', 'Droits': 'Gallica, Bibliothèque nationale de France', 'Emma Bondoerffer': 'Transcription, Balisage, Indexation', 'Anaïs Mazoué': '', 'Teklia': '', 'Hippolyte Faré': '', 'Corto Rolaz': '', 'Octave Philibert': '', 'Alessia Avena': '', 'Youssouf Diawara': '', 'Julia Castiglione': '', 'Anna Sconza': '', 'Irene Calcagno': '', 'Memofonte': '', 'ATIR': '', 'Pierre Husson': '', 'Carla Tricon': '', 'Nicolò Zanolli': '', 'Elisa Bonaiuti': '', 'NiveauTranscription': 'édition complète', 'SpecificitesXML': '', 'StructureXML': 'body avec div des heading Transkribus'}, {'Nom': 'Sanzio, Castiglione', 'Prenom': 'Raphaël, Baldassarre', 'ISNI': 'https://isni.org/isni/000000012136483X;  https://isni.org/isni/0000000121007795', 'DBI/ARK': 'https://data.bnf.fr/ark:/12148/cb12215591q ; https://data.bnf.fr/ark:/12148/cb123195492', 'Titre': 'Lettera a Leone X ...
# Header généré avec succès : outputheader.xml
